# %%
import importlib
import Antiprint
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
import numpy as np
from qutip import *
from qutip.solver import Options, Result, config, _solver_safety_check
# %matplotlib notebook

# %%
importlib.reload(Antiprint)

N=4
a=1
timesteps=20
ntraj=200
statelist=[]
opts=Options(store_states=True,store_final_state=True,ntraj=200)

disavgs=1
i=1
radii=[0.01,0.5,1.0,1.5,2,2.5,3]
start_up_atom = 0
start_down_atom=3
read_out_atom = 3

Antiprint.call(N,radii,start_up_atom,start_down_atom,read_out_atom)
# Out:
# Interaction Coefficient over one-half EIT bandwidth:   0.215
# Interparticle spacing in units of [Critical Radius R]:  100.000
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   0.794
# Interparticle spacing in units of [Critical Radius R]:   2.000
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   1.000
# Interparticle spacing in units of [Critical Radius R]:   1.000
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   1.145
# Interparticle spacing in units of [Critical Radius R]:   0.667
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   1.260
# Interparticle spacing in units of [Critical Radius R]:   0.500
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   1.357
# Interparticle spacing in units of [Critical Radius R]:   0.400
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Interaction Coefficient over one-half EIT bandwidth:   1.442
# Interparticle spacing in units of [Critical Radius R]:   0.333
# Start up-atom: 0 Start down-atom: 3   , Readout atom: 3
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
